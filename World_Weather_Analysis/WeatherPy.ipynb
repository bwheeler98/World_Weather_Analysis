# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import citipy dependency
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 616

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_API_key

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
url = "https://api.openweathermap.org/data/2.5/weather?lat&appid=" + weather_API_key  
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?lat&appid=c32d79d7cec06572e72e6c0f49713853'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | misratah
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | byron bay
# Processing Record 5 of Set 1 | clyde river
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | turukhansk
# Processing Record 8 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 12 of Set 1 | sakakah
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | akdepe
# Processing Record 15 of Set 1 | pimenta bueno
# Processing Record 16 of Set 1 | ekibastuz
# Processing Record 17 of Set 1 | staryy nadym
# Processing Record 18 of Set 1 | quatre cocos
# Processing Record 19 of Set 1 | filadelfia
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | mohan
# Processing Record 23 of Set 1 | almeirim
# Processing Record 24 of Set 1 | trelew
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | balkanabat
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | kidal
# Processing Record 31 of Set 1 | grindavik
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | bahar
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | lavrentiya
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | loreto
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | nioro
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | kilakarai
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | rumford
# Processing Record 48 of Set 1 | ostrovnoy
# Processing Record 49 of Set 1 | ebolowa
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 2 | provideniya
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | kloulklubed
# Processing Record 7 of Set 2 | oranjemund
# Processing Record 8 of Set 2 | lorengau
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | puerto baquerizo moreno
# Processing Record 11 of Set 2 | mooi river
# City not found. Skipping...
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | kruisfontein
# Processing Record 14 of Set 2 | braganca
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | japura
# Processing Record 17 of Set 2 | caravelas
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | adrar
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | ahar
# Processing Record 26 of Set 2 | simao
# Processing Record 27 of Set 2 | gravelbourg
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | pampierstad
# Processing Record 35 of Set 2 | zyryanka
# Processing Record 36 of Set 2 | plettenberg bay
# Processing Record 37 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | tessalit
# Processing Record 40 of Set 2 | ingham
# Processing Record 41 of Set 2 | henties bay
# Processing Record 42 of Set 2 | polyarnyy
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | praia da vitoria
# Processing Record 50 of Set 2 | kaeo
# Processing Record 1 of Set 3 | yumen
# Processing Record 2 of Set 3 | lisakovsk
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | prince rupert
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | manturovo
# Processing Record 8 of Set 3 | syracuse
# Processing Record 9 of Set 3 | tazovskiy
# Processing Record 10 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 3 | xining
# Processing Record 12 of Set 3 | vincennes
# Processing Record 13 of Set 3 | areia branca
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | hami
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | moosomin
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | pisco
# Processing Record 20 of Set 3 | ust-ilimsk
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | champasak
# Processing Record 23 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 3 | gorin
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | obo
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | kuala selangor
# Processing Record 29 of Set 3 | garden city
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | jibuti
# Processing Record 32 of Set 3 | la ronge
# Processing Record 33 of Set 3 | puerto escondido
# Processing Record 34 of Set 3 | simoes
# Processing Record 35 of Set 3 | christchurch
# Processing Record 36 of Set 3 | san carlos de bariloche
# Processing Record 37 of Set 3 | leningradskiy
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | cooma
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | grand gaube
# Processing Record 42 of Set 3 | palaikastron
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | agadez
# Processing Record 45 of Set 3 | jinchang
# Processing Record 46 of Set 3 | itacoatiara
# Processing Record 47 of Set 3 | nome
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | cape town
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | coihaique
# Processing Record 2 of Set 4 | tura
# Processing Record 3 of Set 4 | mehamn
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | gari
# Processing Record 6 of Set 4 | arman
# Processing Record 7 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | road town
# Processing Record 10 of Set 4 | souillac
# Processing Record 11 of Set 4 | ust-kuyga
# Processing Record 12 of Set 4 | zhigansk
# Processing Record 13 of Set 4 | tezu
# Processing Record 14 of Set 4 | andros town
# Processing Record 15 of Set 4 | aksarka
# Processing Record 16 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 4 | solnechnyy
# Processing Record 18 of Set 4 | anadyr
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | ahome
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | samarai
# Processing Record 23 of Set 4 | nanning
# Processing Record 24 of Set 4 | coos bay
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | juneau
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | zdvinsk
# Processing Record 29 of Set 4 | yarensk
# Processing Record 30 of Set 4 | kijang
# Processing Record 31 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | sikonge
# Processing Record 34 of Set 4 | sao joao do piaui
# Processing Record 35 of Set 4 | urumqi
# Processing Record 36 of Set 4 | yankton
# Processing Record 37 of Set 4 | wadi
# Processing Record 38 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 4 | mackay
# Processing Record 40 of Set 4 | constitucion
# Processing Record 41 of Set 4 | bouloupari
# Processing Record 42 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 4 | senneterre
# Processing Record 44 of Set 4 | campo gobierno
# Processing Record 45 of Set 4 | cabo san lucas
# Processing Record 46 of Set 4 | novoagansk
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | tasiilaq
# Processing Record 49 of Set 4 | haifa
# Processing Record 50 of Set 4 | laguna
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | honningsvag
# Processing Record 3 of Set 5 | pinczow
# Processing Record 4 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 5 | koungou
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | la palma
# Processing Record 9 of Set 5 | najran
# Processing Record 10 of Set 5 | santa cruz
# Processing Record 11 of Set 5 | tara
# Processing Record 12 of Set 5 | sale
# Processing Record 13 of Set 5 | khatanga
# Processing Record 14 of Set 5 | yulara
# Processing Record 15 of Set 5 | adre
# Processing Record 16 of Set 5 | bozdar
# Processing Record 17 of Set 5 | taganak
# Processing Record 18 of Set 5 | lagoa
# Processing Record 19 of Set 5 | keetmanshoop
# Processing Record 20 of Set 5 | katsuura
# Processing Record 21 of Set 5 | villa carlos paz
# Processing Record 22 of Set 5 | chapais
# Processing Record 23 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 5 | paamiut
# Processing Record 25 of Set 5 | upernavik
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | tabou
# Processing Record 28 of Set 5 | pacific grove
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 5 | biltine
# Processing Record 31 of Set 5 | beatrice
# Processing Record 32 of Set 5 | vao
# Processing Record 33 of Set 5 | broome
# Processing Record 34 of Set 5 | thompson
# Processing Record 35 of Set 5 | kuytun
# Processing Record 36 of Set 5 | sistranda
# Processing Record 37 of Set 5 | leh
# Processing Record 38 of Set 5 | sheltozero
# Processing Record 39 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 40 of Set 5 | dingle
# Processing Record 41 of Set 5 | takaungu
# Processing Record 42 of Set 5 | ulladulla
# Processing Record 43 of Set 5 | glasgow
# Processing Record 44 of Set 5 | bontang
# Processing Record 45 of Set 5 | kariba
# Processing Record 46 of Set 5 | anchorage
# Processing Record 47 of Set 5 | stokmarknes
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | basey
# Processing Record 50 of Set 5 | sosnovka
# Processing Record 1 of Set 6 | champerico
# Processing Record 2 of Set 6 | diego de almagro
# Processing Record 3 of Set 6 | rundu
# Processing Record 4 of Set 6 | rocha
# Processing Record 5 of Set 6 | marzuq
# Processing Record 6 of Set 6 | soledar
# Processing Record 7 of Set 6 | cilegon
# Processing Record 8 of Set 6 | bay roberts
# Processing Record 9 of Set 6 | nouadhibou
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | teya
# Processing Record 12 of Set 6 | mandalgovi
# Processing Record 13 of Set 6 | hasaki
# Processing Record 14 of Set 6 | karratha
# Processing Record 15 of Set 6 | srednekolymsk
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | shelburne
# Processing Record 18 of Set 6 | visby
# Processing Record 19 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | fortuna
# Processing Record 22 of Set 6 | bilma
# Processing Record 23 of Set 6 | eureka
# Processing Record 24 of Set 6 | pagman
# City not found. Skipping...
# Processing Record 25 of Set 6 | netrakona
# Processing Record 26 of Set 6 | kropotkin
# Processing Record 27 of Set 6 | hokitika
# Processing Record 28 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | avera
# Processing Record 30 of Set 6 | el zulia
# Processing Record 31 of Set 6 | kahului
# Processing Record 32 of Set 6 | copiapo
# Processing Record 33 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 6 | flin flon
# Processing Record 35 of Set 6 | wisconsin rapids
# Processing Record 36 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 6 | muros
# Processing Record 38 of Set 6 | guerrero negro
# Processing Record 39 of Set 6 | mayo
# Processing Record 40 of Set 6 | saint-joseph
# Processing Record 41 of Set 6 | yarmouth
# Processing Record 42 of Set 6 | morondava
# Processing Record 43 of Set 6 | mocuba
# Processing Record 44 of Set 6 | trofors
# Processing Record 45 of Set 6 | russell
# Processing Record 46 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 6 | severomuysk
# Processing Record 48 of Set 6 | sur
# Processing Record 49 of Set 6 | tual
# Processing Record 50 of Set 6 | mizdah
# Processing Record 1 of Set 7 | alice springs
# Processing Record 2 of Set 7 | yuancheng
# Processing Record 3 of Set 7 | campeche
# Processing Record 4 of Set 7 | poum
# Processing Record 5 of Set 7 | priiskovyy
# Processing Record 6 of Set 7 | agadir
# Processing Record 7 of Set 7 | jiuquan
# Processing Record 8 of Set 7 | lima
# Processing Record 9 of Set 7 | port hedland
# Processing Record 10 of Set 7 | yendi
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | xiongyue
# Processing Record 13 of Set 7 | soldotna
# Processing Record 14 of Set 7 | northam
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 7 | luderitz
# Processing Record 17 of Set 7 | male
# Processing Record 18 of Set 7 | samana
# Processing Record 19 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 7 | shitkino
# Processing Record 21 of Set 7 | olinda
# Processing Record 22 of Set 7 | kendari
# Processing Record 23 of Set 7 | torbay
# Processing Record 24 of Set 7 | bargi
# Processing Record 25 of Set 7 | atasu
# Processing Record 26 of Set 7 | zwettl
# Processing Record 27 of Set 7 | harnosand
# Processing Record 28 of Set 7 | carlsbad
# Processing Record 29 of Set 7 | port blair
# Processing Record 30 of Set 7 | labuhan
# Processing Record 31 of Set 7 | rio brilhante
# Processing Record 32 of Set 7 | berlevag
# Processing Record 33 of Set 7 | tromso
# Processing Record 34 of Set 7 | esperance
# Processing Record 35 of Set 7 | palatka
# Processing Record 36 of Set 7 | hovd
# Processing Record 37 of Set 7 | kroya
# Processing Record 38 of Set 7 | saint-pierre
# Processing Record 39 of Set 7 | suzuka
# Processing Record 40 of Set 7 | verkhnevilyuysk
# Processing Record 41 of Set 7 | borlange
# City not found. Skipping...
# Processing Record 42 of Set 7 | arlit
# Processing Record 43 of Set 7 | nanortalik
# Processing Record 44 of Set 7 | college
# Processing Record 45 of Set 7 | general roca
# Processing Record 46 of Set 7 | luganville
# Processing Record 47 of Set 7 | cervo
# Processing Record 48 of Set 7 | inongo
# Processing Record 49 of Set 7 | rehoboth
# Processing Record 50 of Set 7 | beloha
# Processing Record 1 of Set 8 | seoul
# Processing Record 2 of Set 8 | ngunguru
# Processing Record 3 of Set 8 | lata
# Processing Record 4 of Set 8 | mitsamiouli
# Processing Record 5 of Set 8 | aban
# Processing Record 6 of Set 8 | luanda
# Processing Record 7 of Set 8 | nemuro
# Processing Record 8 of Set 8 | roma
# Processing Record 9 of Set 8 | belmonte
# Processing Record 10 of Set 8 | duncan
# Processing Record 11 of Set 8 | folldal
# Processing Record 12 of Set 8 | buin
# Processing Record 13 of Set 8 | marystown
# Processing Record 14 of Set 8 | kant
# Processing Record 15 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 8 | high level
# Processing Record 17 of Set 8 | katangli
# Processing Record 18 of Set 8 | buala
# Processing Record 19 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 8 | los llanos de aridane
# Processing Record 21 of Set 8 | ayacucho
# Processing Record 22 of Set 8 | rafraf
# Processing Record 23 of Set 8 | basco
# Processing Record 24 of Set 8 | verkhnetulomskiy
# Processing Record 25 of Set 8 | maniitsoq
# Processing Record 26 of Set 8 | sangrur
# Processing Record 27 of Set 8 | san jose de gracia
# Processing Record 28 of Set 8 | maldonado
# Processing Record 29 of Set 8 | faya
# Processing Record 30 of Set 8 | sitka
# Processing Record 31 of Set 8 | skegness
# Processing Record 32 of Set 8 | santa cruz do rio pardo
# Processing Record 33 of Set 8 | aasiaat
# Processing Record 34 of Set 8 | yar-sale
# Processing Record 35 of Set 8 | izumo
# Processing Record 36 of Set 8 | nyrob
# Processing Record 37 of Set 8 | kavaratti
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | ruidoso
# Processing Record 40 of Set 8 | sishui
# Processing Record 41 of Set 8 | xiongzhou
# Processing Record 42 of Set 8 | vila franca do campo
# Processing Record 43 of Set 8 | marquard
# Processing Record 44 of Set 8 | ipora
# Processing Record 45 of Set 8 | sao filipe
# Processing Record 46 of Set 8 | mount isa
# Processing Record 47 of Set 8 | issoire
# Processing Record 48 of Set 8 | januaria
# Processing Record 49 of Set 8 | bati
# Processing Record 50 of Set 8 | kushima
# Processing Record 1 of Set 9 | dunedin
# Processing Record 2 of Set 9 | nelson bay
# Processing Record 3 of Set 9 | izvoare
# Processing Record 4 of Set 9 | banfora
# Processing Record 5 of Set 9 | vanimo
# Processing Record 6 of Set 9 | ormara
# Processing Record 7 of Set 9 | aleksandrovskoye
# Processing Record 8 of Set 9 | evensk
# Processing Record 9 of Set 9 | santarem
# Processing Record 10 of Set 9 | namatanai
# Processing Record 11 of Set 9 | macklin
# Processing Record 12 of Set 9 | san vicente
# Processing Record 13 of Set 9 | keti bandar
# Processing Record 14 of Set 9 | ambulu
# Processing Record 15 of Set 9 | baykit
# Processing Record 16 of Set 9 | ouadda
# Processing Record 17 of Set 9 | abha
# Processing Record 18 of Set 9 | san ignacio
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | imeni poliny osipenko
# Processing Record 21 of Set 9 | great bend
# Processing Record 22 of Set 9 | boqueirao
# Processing Record 23 of Set 9 | wyndham
# Processing Record 24 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 9 | polignano a mare
# Processing Record 26 of Set 9 | norden
# Processing Record 27 of Set 9 | amapa
# Processing Record 28 of Set 9 | andenes
# Processing Record 29 of Set 9 | sorland
# Processing Record 30 of Set 9 | dhidhdhoo
# Processing Record 31 of Set 9 | nortelandia
# Processing Record 32 of Set 9 | los algarrobos
# Processing Record 33 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 34 of Set 9 | aykhal
# Processing Record 35 of Set 9 | tiksi
# Processing Record 36 of Set 9 | catuday
# Processing Record 37 of Set 9 | jiaohe
# Processing Record 38 of Set 9 | helena
# Processing Record 39 of Set 9 | zabaykalsk
# Processing Record 40 of Set 9 | ucluelet
# Processing Record 41 of Set 9 | alekseyevskoye
# Processing Record 42 of Set 9 | ganzhou
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | molochnoye
# Processing Record 45 of Set 9 | iskateley
# Processing Record 46 of Set 9 | chirilagua
# Processing Record 47 of Set 9 | buraydah
# Processing Record 48 of Set 9 | bathsheba
# Processing Record 49 of Set 9 | vardo
# Processing Record 50 of Set 9 | valparaiso
# Processing Record 1 of Set 10 | vetlanda
# Processing Record 2 of Set 10 | vila velha
# Processing Record 3 of Set 10 | shache
# Processing Record 4 of Set 10 | bela
# Processing Record 5 of Set 10 | ituacu
# Processing Record 6 of Set 10 | bogorodskoye
# Processing Record 7 of Set 10 | mbini
# Processing Record 8 of Set 10 | berdigestyakh
# Processing Record 9 of Set 10 | cap malheureux
# Processing Record 10 of Set 10 | zhob
# Processing Record 11 of Set 10 | singapore
# Processing Record 12 of Set 10 | liverpool
# Processing Record 13 of Set 10 | wangqing
# Processing Record 14 of Set 10 | shingu
# Processing Record 15 of Set 10 | mananara
# Processing Record 16 of Set 10 | lake city
# Processing Record 17 of Set 10 | half moon bay
# Processing Record 18 of Set 10 | kalengwa
# Processing Record 19 of Set 10 | lompoc
# Processing Record 20 of Set 10 | rawson
# Processing Record 21 of Set 10 | koumac
# Processing Record 22 of Set 10 | forbes
# Processing Record 23 of Set 10 | coahuayana
# Processing Record 24 of Set 10 | hamilton
# Processing Record 25 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 26 of Set 10 | camacha
# Processing Record 27 of Set 10 | mayor pablo lagerenza
# Processing Record 28 of Set 10 | katherine
# Processing Record 29 of Set 10 | tamandare
# Processing Record 30 of Set 10 | remanso
# Processing Record 31 of Set 10 | sharan
# Processing Record 32 of Set 10 | svetlyy
# Processing Record 33 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 10 | leeuwarden
# Processing Record 35 of Set 10 | khandyga
# Processing Record 36 of Set 10 | wisla
# Processing Record 37 of Set 10 | atambua
# Processing Record 38 of Set 10 | malangali
# Processing Record 39 of Set 10 | inhambane
# Processing Record 40 of Set 10 | jesus carranza
# Processing Record 41 of Set 10 | faanui
# Processing Record 42 of Set 10 | husavik
# Processing Record 43 of Set 10 | estevan
# Processing Record 44 of Set 10 | yugo-kamskiy
# Processing Record 45 of Set 10 | gopalpur
# Processing Record 46 of Set 10 | iqaluit
# Processing Record 47 of Set 10 | guilin
# Processing Record 48 of Set 10 | narsaq
# Processing Record 49 of Set 10 | hanyang
# Processing Record 50 of Set 10 | kashi
# Processing Record 1 of Set 11 | jiaonan
# Processing Record 2 of Set 11 | takab
# Processing Record 3 of Set 11 | san matias
# Processing Record 4 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 11 | acapulco
# Processing Record 6 of Set 11 | saint-francois
# Processing Record 7 of Set 11 | sisimiut
# Processing Record 8 of Set 11 | waipawa
# Processing Record 9 of Set 11 | springdale
# Processing Record 10 of Set 11 | la grande
# Processing Record 11 of Set 11 | haimen
# Processing Record 12 of Set 11 | qaqortoq
# Processing Record 13 of Set 11 | dwarka
# Processing Record 14 of Set 11 | matamoros
# Processing Record 15 of Set 11 | novobelokatay
# Processing Record 16 of Set 11 | okhotsk
# Processing Record 17 of Set 11 | axim
# Processing Record 18 of Set 11 | vartej
# Processing Record 19 of Set 11 | abu samrah
# Processing Record 20 of Set 11 | galveston
# Processing Record 21 of Set 11 | haines junction
# Processing Record 22 of Set 11 | jiexiu
# Processing Record 23 of Set 11 | matara
# Processing Record 24 of Set 11 | hays
# Processing Record 25 of Set 11 | broken hill
# Processing Record 26 of Set 11 | cairns
# Processing Record 27 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 11 | ahipara
# Processing Record 29 of Set 11 | ambon
# Processing Record 30 of Set 11 | nabire
# Processing Record 31 of Set 11 | piacabucu
# Processing Record 32 of Set 11 | kawalu
# Processing Record 33 of Set 11 | tabas
# Processing Record 34 of Set 11 | itabirito
# Processing Record 35 of Set 11 | taybad
# Processing Record 36 of Set 11 | nuuk
# Processing Record 37 of Set 11 | bartow
# Processing Record 38 of Set 11 | baghdad
# Processing Record 39 of Set 11 | sompeta
# Processing Record 40 of Set 11 | ugoofaaru
# Processing Record 41 of Set 11 | chipping sodbury
# Processing Record 42 of Set 11 | kungurtug
# Processing Record 43 of Set 11 | conceicao da barra
# Processing Record 44 of Set 11 | geraldton
# Processing Record 45 of Set 11 | saint-leu
# Processing Record 46 of Set 11 | villa del rosario
# Processing Record 47 of Set 11 | guarapari
# Processing Record 48 of Set 11 | batemans bay
# Processing Record 49 of Set 11 | ewa beach
# Processing Record 50 of Set 11 | naze
# Processing Record 1 of Set 12 | gainesville
# Processing Record 2 of Set 12 | mwinilunga
# Processing Record 3 of Set 12 | iracoubo
# Processing Record 4 of Set 12 | brae
# Processing Record 5 of Set 12 | riyadh
# Processing Record 6 of Set 12 | umm kaddadah
# Processing Record 7 of Set 12 | san policarpo
# Processing Record 8 of Set 12 | erzurum
# Processing Record 9 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 10 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 12 | severobaykalsk
# Processing Record 12 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 12 | panaba
# Processing Record 14 of Set 12 | katha
# City not found. Skipping...
# Processing Record 15 of Set 12 | pericos
# Processing Record 16 of Set 12 | nkayi
# Processing Record 17 of Set 12 | dukat
# Processing Record 18 of Set 12 | helong
# Processing Record 19 of Set 12 | kazachinskoye
# Processing Record 20 of Set 12 | ponta delgada
# Processing Record 21 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 22 of Set 12 | bitung
# Processing Record 23 of Set 12 | yurimaguas
# Processing Record 24 of Set 12 | vangaindrano
# Processing Record 25 of Set 12 | egvekinot
# Processing Record 26 of Set 12 | khudumelapye
# Processing Record 27 of Set 12 | jales
# Processing Record 28 of Set 12 | los negros
# Processing Record 29 of Set 12 | walvis bay
# Processing Record 30 of Set 12 | tambovka
# Processing Record 31 of Set 12 | porgera
# Processing Record 32 of Set 12 | pringsewu
# Processing Record 33 of Set 12 | dongsheng
# Processing Record 34 of Set 12 | poronaysk
# Processing Record 35 of Set 12 | fairbanks
# Processing Record 36 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 12 | grootfontein
# Processing Record 38 of Set 12 | innisfail
# Processing Record 39 of Set 12 | woudenberg
# Processing Record 40 of Set 12 | kralendijk
# Processing Record 41 of Set 12 | moron
# Processing Record 42 of Set 12 | padang
# Processing Record 43 of Set 12 | bagan
# Processing Record 44 of Set 12 | venezuela
# Processing Record 45 of Set 12 | vostok
# Processing Record 46 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 47 of Set 12 | tadpatri
# Processing Record 48 of Set 12 | iwaki
# Processing Record 49 of Set 12 | ivaipora
# Processing Record 50 of Set 12 | fort nelson
# Processing Record 1 of Set 13 | wa
# City not found. Skipping...
# Processing Record 2 of Set 13 | buchanan
# Processing Record 3 of Set 13 | sinnamary
# Processing Record 4 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 13 | tianpeng
# Processing Record 6 of Set 13 | bubaque
# Processing Record 7 of Set 13 | moerai
# Processing Record 8 of Set 13 | kudahuvadhoo
# Processing Record 9 of Set 13 | taoudenni
# Processing Record 10 of Set 13 | tiznit
# Processing Record 11 of Set 13 | zaplavnoye
# Processing Record 12 of Set 13 | letterkenny
# Processing Record 13 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 13 | bandarbeyla
# Processing Record 15 of Set 13 | kamenka
# Processing Record 16 of Set 13 | ha tinh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 566

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo  19.7297 -155.0900    301.08        82         100
# 1        Misratah  32.3754   15.0925    290.58        74          91
# 2          Albany  42.6001  -73.9662    288.46        37         100
# 3       Byron Bay -28.6500  153.6167    293.12        68         100
# 4     Clyde River  70.4692  -68.5914    260.28        85         100
# 5  Port Elizabeth -33.9180   25.5701    285.55        84           0
# 6      Turukhansk  65.8167   87.9833    261.32        92          29
# 7  Ribeira Grande  38.5167  -28.7000    288.24        69          71
# 8         Sakakah  29.9697   40.2064    292.91        58          87
# 9       Busselton -33.6500  115.3333    290.61        60          99
#
#    Wind Speed Country                 Date
# 0        6.17      US  2022-04-26 00:20:50
# 1        3.91      LY  2022-04-26 00:20:59
# 2        0.89      US  2022-04-26 00:18:37
# 3        2.61      AU  2022-04-26 00:20:59
# 4        8.75      CA  2022-04-26 00:18:08
# 5        2.57      ZA  2022-04-26 00:19:37
# 6        1.71      RU  2022-04-26 00:21:00
# 7        3.78      PT  2022-04-26 00:21:01
# 8        3.51      SA  2022-04-26 00:21:01
# 9        6.63      AU  2022-04-26 00:21:02

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0            Hilo      US  2022-04-26 00:20:50  19.7297 -155.0900    301.08
# 1        Misratah      LY  2022-04-26 00:20:59  32.3754   15.0925    290.58
# 2          Albany      US  2022-04-26 00:18:37  42.6001  -73.9662    288.46
# 3       Byron Bay      AU  2022-04-26 00:20:59 -28.6500  153.6167    293.12
# 4     Clyde River      CA  2022-04-26 00:18:08  70.4692  -68.5914    260.28
# 5  Port Elizabeth      ZA  2022-04-26 00:19:37 -33.9180   25.5701    285.55
# 6      Turukhansk      RU  2022-04-26 00:21:00  65.8167   87.9833    261.32
# 7  Ribeira Grande      PT  2022-04-26 00:21:01  38.5167  -28.7000    288.24
# 8         Sakakah      SA  2022-04-26 00:21:01  29.9697   40.2064    292.91
# 9       Busselton      AU  2022-04-26 00:21:02 -33.6500  115.3333    290.61
#
#    Humidity  Cloudiness  Wind Speed
# 0        82         100        6.17
# 1        74          91        3.91
# 2        37         100        0.89
# 3        68         100        2.61
# 4        85         100        8.75
# 5        84           0        2.57
# 6        92          29        1.71
# 7        69          71        3.78
# 8        58          87        3.51
# 9        60          99        6.63

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
